# %% [markdown]
# <a href="https://colab.research.google.com/github/phamquiluan/baro/blob/main/tutorials/reproduce_multivariate_bocpd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Reproduction of Multivariate BOCPD
#
# In this notebook, we reproduce the anomaly detection output from Multivariate BOCPD module on the Online Boutique dataset.

# %% [markdown]
# ## Install BARO and import packages

# %%
# !pip install -q fse-baro

# %%
import os
import glob
import json
import warnings
from os.path import join, dirname, basename
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np

from baro.anomaly_detection import bocpd
from baro._bocpd import online_changepoint_detection, partial, constant_hazard, MultivariateT
from baro.utility import load_json, drop_constant, download_data

# %% [markdown]
# ## Download Online Boutique dataset from Zenodo

# %%
download_data("https://zenodo.org/records/11046533/files/fse-ob.zip?download=1", "fse-ob.zip")
import zipfile
os.makedirs("data")
with zipfile.ZipFile("fse-ob.zip", 'r') as file:
    file.extractall("data")
# Out:
# Downloading fse-ob.zip..: 100%|██████████| 151M/151M [00:03<00:00, 41.0MiB/s]

# %% [markdown]
# ## Run

# %%
def find_cps(maxes):
    cps = []
    for i in range(1, len(maxes)):
        if abs(maxes[i] - maxes[i-1]) > 1:
        # m_t = m_t-1 +   1
            # print(i)
            cps.append((i, abs(maxes[i] - maxes[i-1])))
    return cps


for data_path in glob.glob("./data/fse-ob/**/simple_data.csv", recursive=True):
    service_metric = basename(dirname(dirname(data_path)))
    case_idx = basename(dirname(data_path))
    data_dir = dirname(data_path)

    # PREPARE DATA
    data = pd.read_csv(data_path)

    # read inject_time, cut data
    with open(join(data_dir, "inject_time.txt")) as f:
        inject_time = int(f.readlines()[0].strip())
    normal_df = data[data["time"] < inject_time].tail(300)
    anomal_df = data[data["time"] >= inject_time].head(300)
    data = pd.concat([normal_df, anomal_df], ignore_index=True)

    # drop extra columns
    selected_cols = []
    for c in data.columns:
        if 'queue-master' in c or 'rabbitmq_' in c: continue
        if "latency-50" in c or "_error" in c:
            selected_cols.append(c)
    data = data[selected_cols]

    # handle na
    data = drop_constant(data)
    data = data.fillna(method="ffill")
    data = data.fillna(0)
    for c in data.columns:
        data[c] = (data[c] - np.min(data[c])) / (np.max(data[c]) - np.min(data[c]))
    data = data.fillna(method="ffill")
    data = data.fillna(0)
    data = data.to_numpy()

    # RUN BOCPD
    R, maxes = online_changepoint_detection(
            data,
            partial(constant_hazard, 50),
            MultivariateT(dims=data.shape[1])
    )
    cps = find_cps(maxes)
    cps = [p[0] for p in cps]

    ############# READ ANOMALY DETECTION OUTPUT ###############
    saved_anomalies_path = join(data_dir, "naive_bocpd.json")
    print(saved_anomalies_path)
    saved_anomalies = load_json(saved_anomalies_path)
    saved_anomalies = [i[0] for i in saved_anomalies]
    print(f"Saved Anomalies: {saved_anomalies[:3]}")

    ############# RUN ANOMALY DETECTION ###############
    print(f"Anomalies Detected: {cps}")
# Out:
# ./data/fse-ob/checkoutservice_delay/5/naive_bocpd.json
# Saved Anomalies: [340, 600]
# Anomalies Detected: [340, 600]
# ./data/fse-ob/checkoutservice_delay/4/naive_bocpd.json
# Saved Anomalies: [347, 600]
# Anomalies Detected: [347, 600]
# ./data/fse-ob/checkoutservice_delay/1/naive_bocpd.json
# Saved Anomalies: [343, 600]
# Anomalies Detected: [343, 600]
# ./data/fse-ob/checkoutservice_delay/3/naive_bocpd.json
# Saved Anomalies: [231, 237, 349]
# Anomalies Detected: [231, 237, 349, 600]
# ./data/fse-ob/checkoutservice_delay/2/naive_bocpd.json
# Saved Anomalies: [351, 554, 558]
# Anomalies Detected: [351, 554, 558, 600]
# ./data/fse-ob/checkoutservice_loss/5/naive_bocpd.json
# Saved Anomalies: [281, 332, 348]
# Anomalies Detected: [281, 332, 348, 354, 359, 457, 549, 577, 597, 600]
# ./data/fse-ob/checkoutservice_loss/4/naive_bocpd.json
# Saved Anomalies: [326, 329, 512]
# Anomalies Detected: [326, 329, 512, 569, 600]
# ./data/fse-ob/checkoutservice_loss/1/naive_bocpd.json
# Saved Anomalies: [243, 260, 332]
# Anomalies Detected: [243, 260, 332, 333, 572, 600]
# ./data/fse-ob/checkoutservice_loss/3/naive_bocpd.json
# Saved Anomalies: [338, 343, 344]
# Anomalies Detected: [338, 343, 344, 365, 366, 435, 437, 511, 600]
# ./data/fse-ob/checkoutservice_loss/2/naive_bocpd.json
# Saved Anomalies: [299, 326, 327]
# Anomalies Detected: [299, 326, 327, 344, 493, 595, 600]
# ./data/fse-ob/productcatalogservice_loss/5/naive_bocpd.json
# Saved Anomalies: [357, 376, 563]
# Anomalies Detected: [357, 376, 563, 600]
# ./data/fse-ob/productcatalogservice_loss/4/naive_bocpd.json
# Saved Anomalies: [340, 353, 356]
# Anomalies Detected: [340, 353, 356, 357, 376, 458, 498, 501, 600]
# ./data/fse-ob/productcatalogservice_loss/1/naive_bocpd.json
# Saved Anomalies: [368, 372, 373]
# Anomalies Detected: [368, 372, 373, 380, 388, 402, 485, 488, 524, 525, 544, 583, 590, 593, 595, 597, 600]
# ./data/fse-ob/productcatalogservice_loss/3/naive_bocpd.json
# Saved Anomalies: [363, 364, 371]
# Anomalies Detected: [363, 364, 371, 374, 388, 410, 486, 492, 514, 518, 531, 547, 600]
# ./data/fse-ob/productcatalogservice_loss/2/naive_bocpd.json
# Saved Anomalies: [69, 70, 234]
# Anomalies Detected: [69, 70, 234, 236, 358, 483, 600]
# ./data/fse-ob/paymentservice_delay/5/naive_bocpd.json
# Saved Anomalies: [254, 259, 338]
# Anomalies Detected: [254, 259, 338, 557, 566, 600]
# ./data/fse-ob/paymentservice_delay/4/naive_bocpd.json
# Saved Anomalies: [104, 106, 209]
# Anomalies Detected: [104, 106, 209, 333, 600]
# ./data/fse-ob/paymentservice_delay/1/naive_bocpd.json
# Saved Anomalies: [66, 67, 340]
# Anomalies Detected: [66, 67, 340, 600]
# ./data/fse-ob/paymentservice_delay/3/naive_bocpd.json
# Saved Anomalies: [330, 490, 494]
# Anomalies Detected: [330, 490, 494, 495, 500, 547, 600]
# ./data/fse-ob/paymentservice_delay/2/naive_bocpd.json
# Saved Anomalies: [337, 486, 488]
# Anomalies Detected: [337, 486, 488, 506, 510, 581, 584, 600]
# ./data/fse-ob/currencyservice_cpu/5/naive_bocpd.json
# Saved Anomalies: [340, 344, 351]
# Anomalies Detected: [340, 344, 351, 371, 456, 489, 600]
# ./data/fse-ob/currencyservice_cpu/4/naive_bocpd.json
# Saved Anomalies: [310, 329, 340]
# Anomalies Detected: [310, 329, 340, 509, 594, 595, 600]
# ./data/fse-ob/currencyservice_cpu/1/naive_bocpd.json
# Saved Anomalies: [238, 242, 268]
# Anomalies Detected: [238, 242, 268, 270, 336, 549, 593, 600]
# ./data/fse-ob/currencyservice_cpu/3/naive_bocpd.json
# Saved Anomalies: [335, 351, 365]
# Anomalies Detected: [335, 351, 365, 566, 600]
# ./data/fse-ob/currencyservice_cpu/2/naive_bocpd.json
# Saved Anomalies: [340, 587, 600]
# Anomalies Detected: [340, 587, 600]
# ./data/fse-ob/currencyservice_delay/5/naive_bocpd.json
# Saved Anomalies: [180, 184, 337]
# Anomalies Detected: [180, 184, 337, 480, 508, 585, 600]
# ./data/fse-ob/currencyservice_delay/4/naive_bocpd.json
# Saved Anomalies: [339, 493, 590]
# Anomalies Detected: [339, 493, 590, 597, 600]
# ./data/fse-ob/currencyservice_delay/1/naive_bocpd.json
# Saved Anomalies: [343, 484, 600]
# Anomalies Detected: [343, 484, 600]
# ./data/fse-ob/currencyservice_delay/3/naive_bocpd.json
# Saved Anomalies: [340, 344, 439]
# Anomalies Detected: [340, 344, 439, 479, 561, 576, 600]
# ./data/fse-ob/currencyservice_delay/2/naive_bocpd.json
# Saved Anomalies: [339, 500, 505]
# Anomalies Detected: [339, 500, 505, 506, 542, 559, 600]
# ./data/fse-ob/currencyservice_mem/5/naive_bocpd.json
# Saved Anomalies: [345, 351, 492]
# Anomalies Detected: [345, 351, 492, 534, 600]
# ./data/fse-ob/currencyservice_mem/4/naive_bocpd.json
# Saved Anomalies: [346, 600]
# Anomalies Detected: [346, 600]
# ./data/fse-ob/currencyservice_mem/1/naive_bocpd.json
# Saved Anomalies: [345, 600]
# Anomalies Detected: [345, 600]
# ./data/fse-ob/currencyservice_mem/3/naive_bocpd.json
# Saved Anomalies: [348, 367, 531]
# Anomalies Detected: [348, 367, 531, 533, 600]
# ./data/fse-ob/currencyservice_mem/2/naive_bocpd.json
# Saved Anomalies: [344, 550, 600]
# Anomalies Detected: [344, 550, 600]
# ./data/fse-ob/cartservice_cpu/5/naive_bocpd.json
# Saved Anomalies: [300, 315, 328]
# Anomalies Detected: [300, 315, 328, 357, 511, 539, 600]
# ./data/fse-ob/cartservice_cpu/4/naive_bocpd.json
# Saved Anomalies: [257, 261, 336]
# Anomalies Detected: [257, 261, 336, 582, 597, 600]
# ./data/fse-ob/cartservice_cpu/1/naive_bocpd.json
# Saved Anomalies: [341, 344, 387]
# Anomalies Detected: [341, 344, 387, 390, 418, 527, 546, 600]
# ./data/fse-ob/cartservice_cpu/3/naive_bocpd.json
# Saved Anomalies: [339, 340, 351]
# Anomalies Detected: [339, 340, 351, 378, 379, 520, 600]
# ./data/fse-ob/cartservice_cpu/2/naive_bocpd.json
# Saved Anomalies: [205, 230, 332]
# Anomalies Detected: [205, 230, 332, 333, 337, 338, 481, 513, 600]
# ./data/fse-ob/cartservice_loss/5/naive_bocpd.json
# Saved Anomalies: [334, 349, 414]
# Anomalies Detected: [334, 349, 414, 576, 600]
# ./data/fse-ob/cartservice_loss/4/naive_bocpd.json
# Saved Anomalies: [367, 368, 369]
# Anomalies Detected: [367, 368, 369, 378, 391, 407, 445, 502, 600]
# ./data/fse-ob/cartservice_loss/1/naive_bocpd.json
# Saved Anomalies: [298, 310, 319]
# Anomalies Detected: [298, 310, 319, 438, 518, 521, 600]
# ./data/fse-ob/cartservice_loss/3/naive_bocpd.json
# Saved Anomalies: [341, 600]
# Anomalies Detected: [341, 600]
# ./data/fse-ob/cartservice_loss/2/naive_bocpd.json
# Saved Anomalies: [180, 201, 257]
# Anomalies Detected: [180, 201, 257, 314, 315, 385, 406, 410, 453, 454, 506, 600]
# ./data/fse-ob/productcatalogservice_delay/5/naive_bocpd.json
# Saved Anomalies: [339, 444, 600]
# Anomalies Detected: [339, 444, 600]
# ./data/fse-ob/productcatalogservice_delay/4/naive_bocpd.json
# Saved Anomalies: [339, 451, 460]
# Anomalies Detected: [339, 451, 460, 499, 600]
# ./data/fse-ob/productcatalogservice_delay/1/naive_bocpd.json
# Saved Anomalies: [108, 110, 133]
# Anomalies Detected: [108, 110, 133, 147, 340, 487, 600]
# ./data/fse-ob/productcatalogservice_delay/3/naive_bocpd.json
# Saved Anomalies: [340, 439, 600]
# Anomalies Detected: [340, 439, 600]
# ./data/fse-ob/productcatalogservice_delay/2/naive_bocpd.json
# Saved Anomalies: [63, 64, 340]
# Anomalies Detected: [63, 64, 340, 454, 600]
# ./data/fse-ob/paymentservice_mem/5/naive_bocpd.json
# Saved Anomalies: [339, 342, 347]
# Anomalies Detected: [339, 342, 347, 531, 532, 600]
# ./data/fse-ob/paymentservice_mem/4/naive_bocpd.json
# Saved Anomalies: [157, 159, 160]
# Anomalies Detected: [157, 159, 160, 177, 320, 321, 352, 354, 600]
# ./data/fse-ob/paymentservice_mem/1/naive_bocpd.json
# Saved Anomalies: [307, 308, 318]
# Anomalies Detected: [307, 308, 318, 319, 321, 322, 348, 357, 600]
# ./data/fse-ob/paymentservice_mem/3/naive_bocpd.json
# Saved Anomalies: [334, 336, 341]
# Anomalies Detected: [334, 336, 341, 347, 435, 600]
# ./data/fse-ob/paymentservice_mem/2/naive_bocpd.json
# Saved Anomalies: [345, 346, 472]
# Anomalies Detected: [345, 346, 472, 474, 475, 480, 520, 521, 600]
# ./data/fse-ob/currencyservice_loss/5/naive_bocpd.json
# Saved Anomalies: [306, 600]
# Anomalies Detected: [306, 600]
# ./data/fse-ob/currencyservice_loss/4/naive_bocpd.json
# Saved Anomalies: [331, 340, 396]
# Anomalies Detected: [331, 340, 396, 398, 435, 516, 580, 600]
# ./data/fse-ob/currencyservice_loss/1/naive_bocpd.json
# Saved Anomalies: [347, 349, 372]
# Anomalies Detected: [347, 349, 372, 397, 398, 552, 600]
# ./data/fse-ob/currencyservice_loss/3/naive_bocpd.json
# Saved Anomalies: [157, 298, 306]
# Anomalies Detected: [157, 298, 306, 333, 600]
# ./data/fse-ob/currencyservice_loss/2/naive_bocpd.json
# Saved Anomalies: [194, 201, 355]
# Anomalies Detected: [194, 201, 355, 371, 410, 502, 505, 600]
# ./data/fse-ob/checkoutservice_cpu/5/naive_bocpd.json
# Saved Anomalies: [355, 358, 371]
# Anomalies Detected: [355, 358, 371, 459, 579, 600]
# ./data/fse-ob/checkoutservice_cpu/4/naive_bocpd.json
# Saved Anomalies: [170, 173, 324]
# Anomalies Detected: [170, 173, 324, 406, 442, 600]
# ./data/fse-ob/checkoutservice_cpu/1/naive_bocpd.json
# Saved Anomalies: [248, 320, 353]
# Anomalies Detected: [248, 320, 353, 369, 371, 469, 474, 479, 600]
# ./data/fse-ob/checkoutservice_cpu/3/naive_bocpd.json
# Saved Anomalies: [264, 354, 355]
# Anomalies Detected: [264, 354, 355, 363, 365, 369, 494, 498, 499, 501, 526, 600]
# ./data/fse-ob/checkoutservice_cpu/2/naive_bocpd.json
# Saved Anomalies: [115, 347, 494]
# Anomalies Detected: [115, 347, 494, 499, 600]
# ./data/fse-ob/productcatalogservice_cpu/5/naive_bocpd.json
# Saved Anomalies: [341, 342, 373]
# Anomalies Detected: [341, 342, 373, 461, 504, 600]
# ./data/fse-ob/productcatalogservice_cpu/4/naive_bocpd.json
# Saved Anomalies: [272, 277, 343]
# Anomalies Detected: [272, 277, 343, 367, 517, 600]
# ./data/fse-ob/productcatalogservice_cpu/1/naive_bocpd.json
# Saved Anomalies: [339, 353, 478]
# Anomalies Detected: [339, 353, 478, 480, 531, 600]
# ./data/fse-ob/productcatalogservice_cpu/3/naive_bocpd.json
# Saved Anomalies: [337, 338, 417]
# Anomalies Detected: [337, 338, 417, 418, 509, 594, 600]
# ./data/fse-ob/productcatalogservice_cpu/2/naive_bocpd.json
# Saved Anomalies: [184, 187, 340]
# Anomalies Detected: [184, 187, 340, 355, 363, 541, 600]
# ./data/fse-ob/cartservice_delay/5/naive_bocpd.json
# Saved Anomalies: [322, 330, 340]
# Anomalies Detected: [322, 330, 340, 600]
# ./data/fse-ob/cartservice_delay/4/naive_bocpd.json
# Saved Anomalies: [311, 317, 333]
# Anomalies Detected: [311, 317, 333, 451, 517, 521, 522, 600]
# ./data/fse-ob/cartservice_delay/1/naive_bocpd.json
# Saved Anomalies: [97, 98, 333]
# Anomalies Detected: [97, 98, 333, 509, 511, 600]
# ./data/fse-ob/cartservice_delay/3/naive_bocpd.json
# Saved Anomalies: [73, 75, 165]
# Anomalies Detected: [73, 75, 165, 168, 337, 338, 600]
# ./data/fse-ob/cartservice_delay/2/naive_bocpd.json
# Saved Anomalies: [335, 600]
# Anomalies Detected: [335, 600]
# ./data/fse-ob/productcatalogservice_mem/5/naive_bocpd.json
# Saved Anomalies: [345, 383, 470]
# Anomalies Detected: [345, 383, 470, 556, 577, 580, 600]
# ./data/fse-ob/productcatalogservice_mem/4/naive_bocpd.json
# Saved Anomalies: [339, 473, 475]
# Anomalies Detected: [339, 473, 475, 517, 518, 600]
# ./data/fse-ob/productcatalogservice_mem/1/naive_bocpd.json
# Saved Anomalies: [325, 340, 341]
# Anomalies Detected: [325, 340, 341, 509, 600]
# ./data/fse-ob/productcatalogservice_mem/3/naive_bocpd.json
# Saved Anomalies: [344, 522, 581]
# Anomalies Detected: [344, 522, 581, 584, 600]
# ./data/fse-ob/productcatalogservice_mem/2/naive_bocpd.json
# Saved Anomalies: [230, 233, 337]
# Anomalies Detected: [230, 233, 337, 594, 599]
# ./data/fse-ob/checkoutservice_mem/5/naive_bocpd.json
# Saved Anomalies: [326, 347, 393]
# Anomalies Detected: [326, 347, 393, 600]
# ./data/fse-ob/checkoutservice_mem/4/naive_bocpd.json
# Saved Anomalies: [326, 353, 370]
# Anomalies Detected: [326, 353, 370, 379, 600]
# ./data/fse-ob/checkoutservice_mem/1/naive_bocpd.json
# Saved Anomalies: [333, 577, 600]
# Anomalies Detected: [333, 577, 600]
# ./data/fse-ob/checkoutservice_mem/3/naive_bocpd.json
# Saved Anomalies: [348, 349, 350]
# Anomalies Detected: [348, 349, 350, 464, 485, 486, 555, 557, 559, 600]
# ./data/fse-ob/checkoutservice_mem/2/naive_bocpd.json
# Saved Anomalies: [357, 358, 373]
# Anomalies Detected: [357, 358, 373, 476, 477, 600]
# ./data/fse-ob/paymentservice_loss/5/naive_bocpd.json
# Saved Anomalies: [555, 568, 600]
# Anomalies Detected: [555, 568, 600]
# ./data/fse-ob/paymentservice_loss/4/naive_bocpd.json
# Saved Anomalies: [133, 227, 250]
# Anomalies Detected: [133, 227, 250, 271, 341, 384, 397, 473, 547, 600]
# ./data/fse-ob/paymentservice_loss/1/naive_bocpd.json
# Saved Anomalies: [332, 339, 415]
# Anomalies Detected: [332, 339, 415, 472, 504, 561, 574, 600]
# ./data/fse-ob/paymentservice_loss/3/naive_bocpd.json
# Saved Anomalies: [384, 385, 506]
# Anomalies Detected: [384, 385, 506, 588, 598, 600]
# ./data/fse-ob/paymentservice_loss/2/naive_bocpd.json
# Saved Anomalies: [227, 231, 316]
# Anomalies Detected: [227, 231, 316, 317, 341, 342, 351, 352, 357, 358, 456, 457, 560, 591, 600]
# ./data/fse-ob/paymentservice_cpu/5/naive_bocpd.json
# Saved Anomalies: [242, 319, 453]
# Anomalies Detected: [242, 319, 453, 455, 524, 525, 529, 530, 534, 535, 600]
# ./data/fse-ob/paymentservice_cpu/4/naive_bocpd.json
# Saved Anomalies: [357, 375, 378]
# Anomalies Detected: [357, 375, 378, 518, 519, 520, 534, 545, 549, 550, 571, 575, 579, 582, 600]
# ./data/fse-ob/paymentservice_cpu/1/naive_bocpd.json
# Saved Anomalies: [324, 425, 433]
# Anomalies Detected: [324, 425, 433, 488, 600]
# ./data/fse-ob/paymentservice_cpu/3/naive_bocpd.json
# Saved Anomalies: [395, 404, 600]
# Anomalies Detected: [395, 404, 600]
# ./data/fse-ob/paymentservice_cpu/2/naive_bocpd.json
# Saved Anomalies: [367, 390, 404]
# Anomalies Detected: [367, 390, 404, 515, 536, 551, 553, 600]
# ./data/fse-ob/cartservice_mem/5/naive_bocpd.json
# Saved Anomalies: [345, 419, 535]
# Anomalies Detected: [345, 419, 535, 539, 566, 567, 600]
# ./data/fse-ob/cartservice_mem/4/naive_bocpd.json
# Saved Anomalies: [345, 348, 357]
# Anomalies Detected: [345, 348, 357, 496, 497, 498, 515, 600]
# ./data/fse-ob/cartservice_mem/1/naive_bocpd.json
# Saved Anomalies: [339, 343, 430]
# Anomalies Detected: [339, 343, 430, 600]
# ./data/fse-ob/cartservice_mem/3/naive_bocpd.json
# Saved Anomalies: [347, 352, 377]
# Anomalies Detected: [347, 352, 377, 450, 497, 600]
# ./data/fse-ob/cartservice_mem/2/naive_bocpd.json
# Saved Anomalies: [324, 325, 336]
# Anomalies Detected: [324, 325, 336, 519, 544, 600]
